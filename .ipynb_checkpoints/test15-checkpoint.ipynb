# %%
import numpy as np
import pandas as pd

# %%
array = np.array([1,2,3,4,5])

# %%
array.ndim
# Out:
# 1

# %%
array = np.array([[1,2,3,4,5]])

# %%
array.ndim
# Out:
# 2

# %%
array = np.array([[[1,2,3,4,5]]])

# %%
array.ndim
# Out:
# 3

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = {"calories": [420, 380, 390], "duration": [50, 40, 45]}
df = pd.DataFrame(data)

# Scatter plot
df.plot(
    kind="scatter",
    x="duration",
    y="calories",
    color="darkorange",
    s=100,
    grid=True,
)
plt.title("Calories Burned vs. Workout Duration")
plt.xlabel("Duration (minutes)")
plt.ylabel("Calories")
plt.show()

# %%
# this is just to 
# ÷see the visualizations , train models , 
# because thereb are lots of changes we need to make in data

# %%
# pandas is the library of python used for data analysis

# %%
# training any model 
# clean , fill null values , duplicate removal , sql as well
# but what if you know python then there is no need to work in sql
# same functionalithy pandas also provides 
# connect with your db in local using pandas 
# select * 
# all ddata will be loaded in pandas 
# then you can perform the data cleaning operations

# %%
# can you create graphs ?
# in pandas and python you can plot the plots eassy to work with
# eassy syntax

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data: correlated + noise
np.random.seed(1)
x = np.random.randn(5000)
y = 1.2 * x + np.random.randn(5000) / 3

# plot:
fig, ax = plt.subplots()

ax.hist2d(x, y, bins=(np.arange(-3, 3, 0.1), np.arange(-3, 3, 0.1)))

ax.set(xlim=(-2, 2), ylim=(-3, 3))

plt.show()

# %%
corr = df.corr()

# %%
import seaborn as sns

# %%
sns.heatmap(corr)
# Out:
# <Axes: >
